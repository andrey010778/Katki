# %%
import pandas as pd
import numpy as np
import plotly.express as px

df = pd.read_csv('Katki-i-lyzhnye-trassy-Sankt-Peterburga.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 24 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   Порядковое число администрации и комитета                    309 non-null    float64
#  1   Название организации  (спортивного объекта)                  309 non-null    object
#  2   Сфера деятельности (вид спорта)                              309 non-null    object
#  3   Тип (каток/лыжная трасса)                                    309 non-null    object
#  4   Адрес                                                        308 non-null    object
#  5   Уточнение адреса                                             194 non-null    object
#  6   Координаты                                                   309 non-null    object
# ...

# %%
df.head()
# Out:
#    Порядковое число администрации и комитета  \
# 0                                     12.001
# 1                                     12.002
# 2                                     12.003
# 3                                     12.004
# 4                                     12.005
#
#          Название организации  (спортивного объекта)  \
# 0  СПб ГБУ «ЦФКСиЗ Невского района» (внутридворов...
# 1  СПб ГБУ «ЦФКСиЗ Невского района» (внутридворов...
# 2  СПб ГБУ «ЦФКСиЗ Невского района» (внутридворов...
# 3  СПб ГБУ «ЦФКСиЗ Невского района» (внутридворов...
# 4  СПб ГБУ «ЦФКСиЗ Невского района» (внутридворов...
#
#                 Сфера деятельности (вид спорта) Тип (каток/лыжная трасса)  \
# 0  Хоккей, фигурное катание, конькобежный спорт                     Каток
# 1  Хоккей, фигурное катание, конькобежный спорт                     Каток
# 2  Хоккей, фигурное катание, конькобежный спорт                     Каток
# ...

# %%
df['Время работы  (расписание)'].unique()
# Out:
# array(['08.00-22.00', '06.00-23.00', '07.00-05.30', '06.00-02.00',
#        '07.00-00.00', '10.00-22.00', '13.00-21.00', '08.00-22.01',
#        'Круглосуточно', '9.00-22.00', '15:00–22:00', '09:00–20:00',
#        'Пн–пт 12:00–22:00, сб, вс 11.00-22.00', '09:00-21:00',
#        '09:00-21:00 пт-сб 09:00-23:00', '13:30-21:00', '23:00-05:00',
#        '10:00-22:00', 'Пн-чт: 11:00-21:00, пт-вс: 11:00-22:30',
#        '10:00-21:30', '11:00-21:00',
#        'Круглосуточно (не для общего пользования)', '07:00-00:00',
#        '06:30-02:00', '06:30-00:00', '09:30-20:00', 'ПОН-ВС 08.00-22.00',
#        'Пн-пт 11:00–13:30; сб 17:00–21:30; вс 09:30–21:30',
#        'С 09:00 до 23:00', 'Ежедневно с 09:00 до 22:00', '06:45-00:15',
#        'По расписанию', 'Ежедневно: 10.00-19.30',
#        'Ежедневно: 07.00-23.00',
#        'Пятница, суббота, воскресенье - 11.00-22.00',
#        'Пятница, суббота, воскресенье: 11.00-22.00',
#        'Ежедневно: 06.15-23.15', 'Ежедневно: 08.00-22.00',
# ...

# %%
df['Время суток (день/ ночь/ день и ночь)'].unique()
# Out:
# array(['День', 'День;ночь', 'Ночь', 'День и ночь', 'День/Ночь', 'день',
#        'день/ночь', 'День/ ночь', 'круглосуточно'], dtype=object)

# %%
df['Время суток (день/ ночь/ день и ночь)'] = df['Время суток (день/ ночь/ день и ночь)'].str.lower()

# %%
df['Время суток (день/ ночь/ день и ночь)'].unique()
# Out:
# array(['день', 'день;ночь', 'ночь', 'день и ночь', 'день/ночь',
#        'день/ ночь', 'круглосуточно'], dtype=object)

# %%
df['Время суток (день/ ночь/ день и ночь)'] = df['Время суток (день/ ночь/ день и ночь)'].str.replace(';', '/')
df['Время суток (день/ ночь/ день и ночь)'] = df['Время суток (день/ ночь/ день и ночь)'].str.replace(' и ', '/')
df['Время суток (день/ ночь/ день и ночь)'] = df['Время суток (день/ ночь/ день и ночь)'].str.replace(' ', '')

# %%
df['Время суток (день/ ночь/ день и ночь)'].unique()
# Out:
# array(['день', 'день/ночь', 'ночь', 'круглосуточно'], dtype=object)

# %%
df.head()
# Out:
#    Порядковое число администрации и комитета  \
# 0                                     12.001
# 1                                     12.002
# 2                                     12.003
# 3                                     12.004
# 4                                     12.005
#
#          Название организации  (спортивного объекта)  \
# 0  СПб ГБУ «ЦФКСиЗ Невского района» (внутридворов...
# 1  СПб ГБУ «ЦФКСиЗ Невского района» (внутридворов...
# 2  СПб ГБУ «ЦФКСиЗ Невского района» (внутридворов...
# 3  СПб ГБУ «ЦФКСиЗ Невского района» (внутридворов...
# 4  СПб ГБУ «ЦФКСиЗ Невского района» (внутридворов...
#
#                 Сфера деятельности (вид спорта) Тип (каток/лыжная трасса)  \
# 0  Хоккей, фигурное катание, конькобежный спорт                     Каток
# 1  Хоккей, фигурное катание, конькобежный спорт                     Каток
# 2  Хоккей, фигурное катание, конькобежный спорт                     Каток
# ...

# %%
df.drop(['Иные услуги (перечень)', 'Уточнение адреса', 'Телефон(ы)'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 21 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   Порядковое число администрации и комитета                    309 non-null    float64
#  1   Название организации  (спортивного объекта)                  309 non-null    object
#  2   Сфера деятельности (вид спорта)                              309 non-null    object
#  3   Тип (каток/лыжная трасса)                                    309 non-null    object
#  4   Адрес                                                        308 non-null    object
#  5   Координаты                                                   309 non-null    object
#  6   Ближайшая станция метро, остановка общественного транспорта  309 non-null    object
# ...

# %%
df['Район'].unique()
# Out:
# array(['Невский', 'Красносельский', 'Адмиралтейский', 'Василеостровский',
#        'Выборгский', 'Калининский', 'Кировский', 'Колпинский',
#        'Красногвардейский', 'Кронштадтский', 'Курортный', 'Московский',
#        'Петроградский', 'Петродворцовый', 'Приморский', 'Пушкинский',
#        'Фрунзенский', 'Центральный'], dtype=object)

# %%
df['Ближайшая станция метро, остановка общественного транспорта'].unique()
# Out:
# array(['Ст. Метро «Улица Дыбенко»', 'Ст. Метро «Обухово»',
#        'Ст. Метро «Улица Дыбенко», «Проспект Большевиков»',
#        'Ст. Метро «Ломоносовская»', 'Ст. Метро «Рыбацкое»',
#        'Ст. Метро «Проспект Большевиков»', 'Ст. М. Ломоносовская',
#        'Ст. Метро «Ломоносовская», ст. Метро «Елизаровская»',
#        'Ст. Метро «Ломоносовская», ст.м.Улица Дыбенко»',
#        'Ст. Метро «Пролетарская»',
#        'Ст. Метро «Улица Дыбенко», ст. Метро «Пр. Большевиков»',
#        'Ст. Метро «Пр. Большевиков»', 'М. Проспект Ветеранов',
#        'М. Пушкинская', 'М. Балтийская', 'М. Нарвская',
#        'М. Адмиралтейская', 'Василеостровская, Приморская',
#        'Василеостровская', 'Приморская', 'М. Озерки',
#        'М. Проспект Просвещения', 'М. Удельная', 'М. Выборгская',
#        'М.Озерки', 'М. Лесная', 'М. Парнас', 'М. Политехническая',
#        'Ст. Метро «Гражданский пр», автобус 153, 176. Ст. Метро «Академическая», автобус 102',
# ...

# %%
df['Наличие камеры хранения (да/нет)'].unique()
# Out:
# array([False,  True])

# %%
df.replace({False: "Нет", True: "Да"}, inplace=True)

# %%
df['Наличие камеры хранения (да/нет)'].unique()
# Out:
# array(['Нет', 'Да'], dtype=object)

# %%
df['Наличие кафе на территории (да/нет)'].unique()
# Out:
# array(['Нет', 'Да'], dtype=object)

# %%
df['Наличие помещения для переодевания (да/нет)'].unique()
# Out:
# array(['Нет', 'Да'], dtype=object)

# %%
df.drop(['Ближайшая станция метро, остановка общественного транспорта', 'Порядковое число администрации и комитета', 'Адрес сайта или  страницы в социальных сетях' ], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 18 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   Название организации  (спортивного объекта)             309 non-null    object
#  1   Сфера деятельности (вид спорта)                         309 non-null    object
#  2   Тип (каток/лыжная трасса)                               309 non-null    object
#  3   Адрес                                                   308 non-null    object
#  4   Координаты                                              309 non-null    object
#  5   Район                                                   309 non-null    object
#  6   Статус (работающий/ временно приостановлено посещение)  309 non-null    object
#  7   Время работы  (расписание)                              309 non-null    object
# ...

# %%
df['Время работы  (расписание)'].unique()
df.drop(['Время работы  (расписание)'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 17 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   Название организации  (спортивного объекта)             309 non-null    object
#  1   Сфера деятельности (вид спорта)                         309 non-null    object
#  2   Тип (каток/лыжная трасса)                               309 non-null    object
#  3   Адрес                                                   308 non-null    object
#  4   Координаты                                              309 non-null    object
#  5   Район                                                   309 non-null    object
#  6   Статус (работающий/ временно приостановлено посещение)  309 non-null    object
#  7   Время суток (день/ ночь/ день и ночь)                   309 non-null    object
# ...

# %%
df['Сфера деятельности (вид спорта)'].unique()
df.drop(['Сфера деятельности (вид спорта)'], axis=1, inplace=True)

# %%
df['Доступность для лиц с нарушениями здоровья'].unique()
df.drop(['Доступность для лиц с нарушениями здоровья'], axis=1, inplace=True)

# %%
df['Тип (каток/лыжная трасса)'].unique()
# Out:
# array(['Каток', 'Лыжная трасса',
#        'Каток (Внутридворовая спортивная площадка)',
#        'Каток (Внутридворовая спортивная площадка) Хоккейная коробка',
#        'Каток с искусственным льдом', 'Хоккейная коробка',
#        'лыжная трасса', 'каток', 'Горнолыжный склон',
#        'Лыжная трасса (протяженность 1,6 км)',
#        'Лыжная трасса (протяженность 1,9 км)',
#        'Лыжная трасса (протяженность 1,2 км)'], dtype=object)

# %%
def clean_facility(name):
    name = name.lower()  # приводим к нижнему регистру
    
    if 'каток' in name or 'хоккейная коробка' in name:
        return 'каток'
    elif 'лыжная трасса' in name:
        return 'лыжная трасса'
    else:
        return 'горнолыжный склон'
    

# Применяем функцию к столбцу
df['Тип (каток/лыжная трасса)'] = df['Тип (каток/лыжная трасса)'].apply(clean_facility)

# %%
df['Тип (каток/лыжная трасса)'].unique()
# Out:
# array(['каток', 'лыжная трасса', 'горнолыжный склон'], dtype=object)

# %%
df['Освещение'].unique()
# Out:
# array(['Имеется', 'Отсутствует', 'Внутридворовое освещение',
#        'Уличное освещение', 'Парковое освещение', 'Имеется (уличное)',
#        'Объект имеет освещение', 'Освещение отсутствует', 'Да', 'Нет',
#        'Имеется частичное освещение', 'Частичное коммунальное освещение',
#        'Внтридворовое освещение', 'нет', 'да', 'внутридворовое освещение',
#        'Внутридворовое', 'Парковое', 'внутридворовое', 'парковое',
#        'отсутствует', 'имеется'], dtype=object)

# %%
df['Статус (работающий/ временно приостановлено посещение)'].unique()
# Out:
# array(['Временно приостановлено посещение', 'Работающий', 'Не работающий',
#        'Посещение временно приостановлено',
#        'Работа объекта приостановлена до ноября 2024г', 'Неработающий',
#        'Работает', 'Не работает',
#        'Работа объекта приостановлена до ноября 2024 г', 'работает',
#        'Работа объекта приостановлена до ноября 2024',
#        'временно приостановлено посещение', 'работающий',
#        'Работа приостановлена до декабря 2024 г'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 15 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   Название организации  (спортивного объекта)             309 non-null    object
#  1   Тип (каток/лыжная трасса)                               309 non-null    object
#  2   Адрес                                                   308 non-null    object
#  3   Координаты                                              309 non-null    object
#  4   Район                                                   309 non-null    object
#  5   Статус (работающий/ временно приостановлено посещение)  309 non-null    object
#  6   Время суток (день/ ночь/ день и ночь)                   309 non-null    object
#  7   Расположение (открытый/закрытый)                        309 non-null    object
# ...

# %%
df['Стоимость услуг (платно/ бесплатно)'].unique()
# Out:
# array(['Бесплатно', 'Платно', nan, 'Платно/ бесплатно',
#        'Платно, бесплатно', 'бесплатно', 'платно', 'Платно/бесплатно',
#        'Бесплатно/ платно', 'Только для обучающихся школы 438',
#        'только для обучающихся ГБПОУ "Академия ледовых видов спорта "Динамо Санкт-Петербург"'],
#       dtype=object)

# %%
df.drop(['Статус (работающий/ временно приостановлено посещение)', 'Стоимость услуг (платно/ бесплатно)'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 13 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Название организации  (спортивного объекта)  309 non-null    object
#  1   Тип (каток/лыжная трасса)                    309 non-null    object
#  2   Адрес                                        308 non-null    object
#  3   Координаты                                   309 non-null    object
#  4   Район                                        309 non-null    object
#  5   Время суток (день/ ночь/ день и ночь)        309 non-null    object
#  6   Расположение (открытый/закрытый)             309 non-null    object
#  7   Наличие проката инвентаря (да/нет)           309 non-null    object
#  8   Наличие услуг инструктора (да/нет)           309 non-null    object
# ...

# %%
df['Расположение (открытый/закрытый)'].unique()
# Out:
# array(['Открытый', 'Крытый', 'Закрытый', 'Закрыртый', 'Открытая',
#        'открытый', 'закрытый', 'открытая', 'Временно закрыто'],
#       dtype=object)

# %%
df['Расположение (открытый/закрытый)'].value_counts()
# Out:
# Расположение (открытый/закрытый)
# Открытый            231
# Закрытый             25
# открытый             20
# Крытый               12
# открытая              9
# закрытый              7
# Открытая              2
# Временно закрыто      2
# Закрыртый             1
# Name: count, dtype: int64

# %%
df['Расположение (открытый/закрытый)'] = df['Расположение (открытый/закрытый)'].str.lower().replace({'закрыртый': 'закрытый', 'крытый': 'закрытый', 'открытая': 'открытый'})

# %%
df['Расположение (открытый/закрытый)'] = df['Расположение (открытый/закрытый)'].replace('временно закрыто', np.nan)

# %%
df['Расположение (открытый/закрытый)'].value_counts()
# Out:
# Расположение (открытый/закрытый)
# открытый    262
# закрытый     45
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 13 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Название организации  (спортивного объекта)  309 non-null    object
#  1   Тип (каток/лыжная трасса)                    309 non-null    object
#  2   Адрес                                        308 non-null    object
#  3   Координаты                                   309 non-null    object
#  4   Район                                        309 non-null    object
#  5   Время суток (день/ ночь/ день и ночь)        309 non-null    object
#  6   Расположение (открытый/закрытый)             307 non-null    object
#  7   Наличие проката инвентаря (да/нет)           309 non-null    object
#  8   Наличие услуг инструктора (да/нет)           309 non-null    object
# ...

# %%
df = df.dropna(subset='Расположение (открытый/закрытый)')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 307 entries, 0 to 308
# Data columns (total 13 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Название организации  (спортивного объекта)  307 non-null    object
#  1   Тип (каток/лыжная трасса)                    307 non-null    object
#  2   Адрес                                        306 non-null    object
#  3   Координаты                                   307 non-null    object
#  4   Район                                        307 non-null    object
#  5   Время суток (день/ ночь/ день и ночь)        307 non-null    object
#  6   Расположение (открытый/закрытый)             307 non-null    object
#  7   Наличие проката инвентаря (да/нет)           307 non-null    object
#  8   Наличие услуг инструктора (да/нет)           307 non-null    object
# ...

# %%
df['Координаты'].head()
# Out:
# 0     59.90078,30.468486
# 1     59.85195,30.467251
# 2     59.914643,30.46422
# 3    59.862895,30.500754
# 4    59.831232,30.508499
# Name: Координаты, dtype: object

# %%
df[['широта', 'долгота']] = df['Координаты'].str.split(',', expand=True)

# Конвертируем в числовой формат (float)
df['широта'] = df['широта'].astype(float)
df['долгота'] = df['долгота'].astype(float)

# %%
df.head()
# Out:
#          Название организации  (спортивного объекта)  \
# 0  СПб ГБУ «ЦФКСиЗ Невского района» (внутридворов...
# 1  СПб ГБУ «ЦФКСиЗ Невского района» (внутридворов...
# 2  СПб ГБУ «ЦФКСиЗ Невского района» (внутридворов...
# 3  СПб ГБУ «ЦФКСиЗ Невского района» (внутридворов...
# 4  СПб ГБУ «ЦФКСиЗ Невского района» (внутридворов...
#
#   Тип (каток/лыжная трасса)  \
# 0                     каток
# 1                     каток
# 2                     каток
# 3                     каток
# 4                     каток
#
#                                                Адрес           Координаты  \
# 0      г. Санкт-Петербург, ул. Дыбенко, д.17, корп.3   59.90078,30.468486
# 1  г. Санкт-Петербург, Запорожская ул., д.23, корп.2   59.85195,30.467251
# 2    г. Санкт-Петербург, Искровский пр., д.6, корп.7   59.914643,30.46422
# 3  г. Санкт-Петербург, Октябрьская наб., д.118, к...  59.862895,30.500754
# 4           г. Санкт-Петербург, Прибрежная ул., д.16  59.831232,30.508499
#
# ...

# %%
fig = px.scatter_map(
    df,
    lat='широта',
    lon='долгота',
    hover_name='Название организации  (спортивного объекта)',
    color='Тип (каток/лыжная трасса)',
    zoom=10
)
fig.show()

# %%
df['Координаты'] = df['Координаты'].apply(
    lambda x: f"[{', '.join(x.split(','))}]")

# %%
df.head()
# Out:
#          Название организации  (спортивного объекта)  \
# 0  СПб ГБУ «ЦФКСиЗ Невского района» (внутридворов...
# 1  СПб ГБУ «ЦФКСиЗ Невского района» (внутридворов...
# 2  СПб ГБУ «ЦФКСиЗ Невского района» (внутридворов...
# 3  СПб ГБУ «ЦФКСиЗ Невского района» (внутридворов...
# 4  СПб ГБУ «ЦФКСиЗ Невского района» (внутридворов...
#
#   Тип (каток/лыжная трасса)  \
# 0                     каток
# 1                     каток
# 2                     каток
# 3                     каток
# 4                     каток
#
#                                                Адрес              Координаты  \
# 0      г. Санкт-Петербург, ул. Дыбенко, д.17, корп.3   [59.90078, 30.468486]
# 1  г. Санкт-Петербург, Запорожская ул., д.23, корп.2   [59.85195, 30.467251]
# 2    г. Санкт-Петербург, Искровский пр., д.6, корп.7   [59.914643, 30.46422]
# 3  г. Санкт-Петербург, Октябрьская наб., д.118, к...  [59.862895, 30.500754]
# 4           г. Санкт-Петербург, Прибрежная ул., д.16  [59.831232, 30.508499]
#
# ...

# %%
df.to_csv('Clear_katki_i_lyzhnye_Spb.csv', index=False, sep=';', encoding='utf-8')
